# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
SEED = 42
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)

seed_everything(SEED) # Seed 고정

# %% [markdown]
# # 데이터 불러오기

# %%
os.chdir('/content/drive/Othercomputers/내 MacBook Air/MLDL/project/open')

# %%
train = pd.read_csv('./train.csv')
val = pd.read_csv('./val.csv')
test = pd.read_csv('./test.csv')
sample_submission = pd.read_csv('./sample_submission.csv')

# %%
train_total = train.iloc[:, 1:]
val_total = val.iloc[:, 1:]
test_total = test.iloc[:, 1:]

# %%
val_total_x = val_total.drop(['Class'], axis=1)
val_total_y = val_total.loc[:, 'Class']

# %%
from sklearn.preprocessing import StandardScaler  # 표준화 
std = StandardScaler()

train_total_std = std.fit_transform(train_total) 
val_total_x_std = std.fit_transform(val_total_x) 
test_total_std = std.fit_transform(test_total)

# %%
selection = [1, 2, 3, 4, 5, 7, 8, 9, 10, 11, 12, 14, 16, 17, 18, 21, 27, 30]
idx = selection-np.ones_like(selection)
def feature_selection(data):
  select_data = data[:,idx]
  return select_data

# %%
select_train = feature_selection(train_total_std)
select_val_x = feature_selection(val_total_x_std)
select_test = feature_selection(test_total_std)

# %% [markdown]
# ## EllipticEnvelope

# %% [markdown]
# #### 라벨링
# * +1 이면 boundary 안에 들어온 값으로 정상 데이터
# * -1 이면 outlier
#
# 정상데이터: 0 , 이상치: 1로 라벨링 수정

# %%
def get_pred_label(model_pred):
  model_pred = np.where(model_pred==1, 0, model_pred)
  model_pred = np.where(model_pred==-1, 1, model_pred)
  return model_pred

# %% [markdown]
# ### EE Model Fit

# %%
from sklearn.covariance import EllipticEnvelope
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report
EE_model = EllipticEnvelope(support_fraction = 0.999, contamination = 0.00112, random_state = 42)

EE_model.fit(select_train)
# Out:
# EllipticEnvelope(contamination=0.00112, random_state=42, support_fraction=0.999)

# %% [markdown]
# ### Predict

# %%
val_EE_pred = EE_model.predict(select_val_x)
val_EE_pred = get_pred_label(val_EE_pred)
val_EE_score = f1_score(val_total_y, val_EE_pred, average='macro')
print(f'Validation F1 Score : [{val_EE_score}]')
print(classification_report(val_total_y, val_EE_pred))
# Out:
# Validation F1 Score : [0.8927516353661109]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.85      0.73      0.79        30
#
#     accuracy                           1.00     28462
#    macro avg       0.92      0.87      0.89     28462
# weighted avg       1.00      1.00      1.00     28462

# %% [markdown]
# ## AutoEncoder

# %%
select_train.shape
# Out:
# (113842, 18)

# %%
import tensorflow as tf
from tensorflow.keras import Model
# Sequential

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import layers
# Conv2D, Conv2DTranspose, Dense, Flatten, Dropout, BatchNormalization, Reshape, LeakyReLU

# %% [markdown]
# ### Model

# %%
input_dim = select_train.shape[1]
output_dim = input_dim
encoding_dim = 128

input_layer = layers.Input(shape=(input_dim, ))

encoder1 = layers.Dense(encoding_dim/2, name='encoder1')(input_layer)
encoder1 = layers.BatchNormalization()(encoder1)
encoder1 = layers.LeakyReLU()(encoder1)

encoder2 = layers.Dense(encoding_dim, name='encoder2')(encoder1)
encoder2 = layers.BatchNormalization()(encoder2)
encoder2 = layers.LeakyReLU()(encoder2)

decoder1 = layers.Dense(encoding_dim/2, name='decoder1')(encoder2)
decoder1 = layers.BatchNormalization()(decoder1)
decoder1 = layers.LeakyReLU()(decoder1)

decoder2 = layers.Dense(output_dim, name='decoder2')(decoder1)

autoencoder = Model(input_layer, decoder2)
autoencoder.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.01))

# %%
print("====== 모델 전체 구조 ======")
print(autoencoder.summary())
# Out:
# ====== 모델 전체 구조 ======
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 18)]              0
#
#  encoder1 (Dense)            (None, 64)                1216
#
#  batch_normalization_19 (Bat  (None, 64)               256
#  chNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 64)                0
#
#  encoder2 (Dense)            (None, 128)               8320
#
#  batch_normalization_20 (Bat  (None, 128)              512
#  chNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 128)               0
#
#  decoder1 (Dense)            (None, 64)                8256
#
#  batch_normalization_21 (Bat  (None, 64)               256
#  chNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 64)                0
#
#  decoder2 (Dense)            (None, 18)                1170
#
# =================================================================
# Total params: 19,986
# Trainable params: 19,474
# Non-trainable params: 512
# _________________________________________________________________
# None

# %% [markdown]
# ### Fit

# %%
EPOCHS = 400
BATCH = 2**14
reduce_lr = ReduceLROnPlateau(monitor='loss', mode='max', factor=0.5, patience=10, min_lr=1e-8, verbose=True)
# es = EarlyStopping(monitor='loss', patience=5, verbose=1)

# %%
hist = autoencoder.fit(select_train, select_train, 
                 epochs=EPOCHS,
                 batch_size=BATCH,
                 callbacks=[reduce_lr],
                 shuffle=True)
# Out:
# Epoch 1/400
# 7/7 [==============================] - 2s 10ms/step - loss: 0.5796 - lr: 0.0100
# Epoch 2/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1187 - lr: 0.0100
# Epoch 3/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0708 - lr: 0.0100
# Epoch 4/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0491 - lr: 0.0100
# Epoch 5/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0381 - lr: 0.0100
# Epoch 6/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0289 - lr: 0.0100
# Epoch 7/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0246 - lr: 0.0100
# Epoch 8/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0207 - lr: 0.0100
# Epoch 9/400
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0183 - lr: 0.0100
# Epoch 10/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0166 - lr: 0.0100
# Epoch 11/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0155
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0154 - lr: 0.0100
# Epoch 12/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0140 - lr: 0.0050
# Epoch 13/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0138 - lr: 0.0050
# Epoch 14/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0130 - lr: 0.0050
# Epoch 15/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0127 - lr: 0.0050
# Epoch 16/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0122 - lr: 0.0050
# Epoch 17/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0119 - lr: 0.0050
# Epoch 18/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0115 - lr: 0.0050
# Epoch 19/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0111 - lr: 0.0050
# Epoch 20/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0114 - lr: 0.0050
# Epoch 21/400
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0108
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0108 - lr: 0.0050
# Epoch 22/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0102 - lr: 0.0025
# Epoch 23/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0100 - lr: 0.0025
# Epoch 24/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0099 - lr: 0.0025
# Epoch 25/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0101 - lr: 0.0025
# Epoch 26/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0097 - lr: 0.0025
# Epoch 27/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0095 - lr: 0.0025
# Epoch 28/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0097 - lr: 0.0025
# Epoch 29/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0094 - lr: 0.0025
# Epoch 30/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0093 - lr: 0.0025
# Epoch 31/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0092
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0094 - lr: 0.0025
# Epoch 32/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0093 - lr: 0.0012
# Epoch 33/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0089 - lr: 0.0012
# Epoch 34/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0091 - lr: 0.0012
# Epoch 35/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0091 - lr: 0.0012
# Epoch 36/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0088 - lr: 0.0012
# Epoch 37/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0088 - lr: 0.0012
# Epoch 38/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0088 - lr: 0.0012
# Epoch 39/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0085 - lr: 0.0012
# Epoch 40/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0084 - lr: 0.0012
# Epoch 41/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0082
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0084 - lr: 0.0012
# Epoch 42/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0084 - lr: 6.2500e-04
# Epoch 43/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0088 - lr: 6.2500e-04
# Epoch 44/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0086 - lr: 6.2500e-04
# Epoch 45/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0085 - lr: 6.2500e-04
# Epoch 46/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0082 - lr: 6.2500e-04
# Epoch 47/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 6.2500e-04
# Epoch 48/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0083 - lr: 6.2500e-04
# Epoch 49/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0083 - lr: 6.2500e-04
# Epoch 50/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 6.2500e-04
# Epoch 51/400
# 7/7 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - lr: 6.2500e-04
# Epoch 52/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0083 - lr: 3.1250e-04
# Epoch 53/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0081 - lr: 3.1250e-04
# Epoch 54/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.1250e-04
# Epoch 55/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0081 - lr: 3.1250e-04
# Epoch 56/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.1250e-04
# Epoch 57/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0084 - lr: 3.1250e-04
# Epoch 58/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0080 - lr: 3.1250e-04
# Epoch 59/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0082 - lr: 3.1250e-04
# Epoch 60/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0084 - lr: 3.1250e-04
# Epoch 61/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0080
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0079 - lr: 3.1250e-04
# Epoch 62/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.5625e-04
# Epoch 63/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 1.5625e-04
# Epoch 64/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0089 - lr: 1.5625e-04
# Epoch 65/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.5625e-04
# Epoch 66/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.5625e-04
# Epoch 67/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.5625e-04
# Epoch 68/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0081 - lr: 1.5625e-04
# Epoch 69/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 1.5625e-04
# Epoch 70/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.5625e-04
# Epoch 71/400
# 7/7 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 71: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0078 - lr: 1.5625e-04
# Epoch 72/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0078 - lr: 7.8125e-05
# Epoch 73/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0080 - lr: 7.8125e-05
# Epoch 74/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 7.8125e-05
# Epoch 75/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0081 - lr: 7.8125e-05
# Epoch 76/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 7.8125e-05
# Epoch 77/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 7.8125e-05
# Epoch 78/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 7.8125e-05
# Epoch 79/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0080 - lr: 7.8125e-05
# Epoch 80/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0079 - lr: 7.8125e-05
# Epoch 81/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0077
# Epoch 81: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 7.8125e-05
# Epoch 82/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 3.9062e-05
# Epoch 83/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0083 - lr: 3.9062e-05
# Epoch 84/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.9062e-05
# Epoch 85/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.9062e-05
# Epoch 86/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 3.9062e-05
# Epoch 87/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 3.9062e-05
# Epoch 88/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 3.9062e-05
# Epoch 89/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0082 - lr: 3.9062e-05
# Epoch 90/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 3.9062e-05
# Epoch 91/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0086
# Epoch 91: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.9062e-05
# Epoch 92/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.9531e-05
# Epoch 93/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.9531e-05
# Epoch 94/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.9531e-05
# Epoch 95/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.9531e-05
# Epoch 96/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.9531e-05
# Epoch 97/400
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0077 - lr: 1.9531e-05
# Epoch 98/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.9531e-05
# Epoch 99/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0083 - lr: 1.9531e-05
# Epoch 100/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 1.9531e-05
# Epoch 101/400
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0078
# Epoch 101: ReduceLROnPlateau reducing learning rate to 9.765624781721272e-06.
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.9531e-05
# Epoch 102/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 9.7656e-06
# Epoch 103/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 9.7656e-06
# Epoch 104/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 9.7656e-06
# Epoch 105/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 9.7656e-06
# Epoch 106/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 9.7656e-06
# Epoch 107/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 9.7656e-06
# Epoch 108/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 9.7656e-06
# Epoch 109/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 9.7656e-06
# Epoch 110/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 9.7656e-06
# Epoch 111/400
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0079
# Epoch 111: ReduceLROnPlateau reducing learning rate to 4.882812390860636e-06.
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0079 - lr: 9.7656e-06
# Epoch 112/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 4.8828e-06
# Epoch 113/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0077 - lr: 4.8828e-06
# Epoch 114/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 4.8828e-06
# Epoch 115/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 4.8828e-06
# Epoch 116/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 4.8828e-06
# Epoch 117/400
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0077 - lr: 4.8828e-06
# Epoch 118/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0077 - lr: 4.8828e-06
# Epoch 119/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0077 - lr: 4.8828e-06
# Epoch 120/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 4.8828e-06
# Epoch 121/400
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0079
# Epoch 121: ReduceLROnPlateau reducing learning rate to 2.441406195430318e-06.
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0079 - lr: 4.8828e-06
# Epoch 122/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 2.4414e-06
# Epoch 123/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0080 - lr: 2.4414e-06
# Epoch 124/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0077 - lr: 2.4414e-06
# Epoch 125/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 2.4414e-06
# Epoch 126/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 2.4414e-06
# Epoch 127/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 2.4414e-06
# Epoch 128/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 2.4414e-06
# Epoch 129/400
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0078 - lr: 2.4414e-06
# Epoch 130/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 2.4414e-06
# Epoch 131/400
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0079
# Epoch 131: ReduceLROnPlateau reducing learning rate to 1.220703097715159e-06.
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0082 - lr: 2.4414e-06
# Epoch 132/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0080 - lr: 1.2207e-06
# Epoch 133/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 1.2207e-06
# Epoch 134/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0076 - lr: 1.2207e-06
# Epoch 135/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 1.2207e-06
# Epoch 136/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0084 - lr: 1.2207e-06
# Epoch 137/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.2207e-06
# Epoch 138/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0077 - lr: 1.2207e-06
# Epoch 139/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 1.2207e-06
# Epoch 140/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0081 - lr: 1.2207e-06
# Epoch 141/400
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0078
# Epoch 141: ReduceLROnPlateau reducing learning rate to 6.103515488575795e-07.
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0077 - lr: 1.2207e-06
# Epoch 142/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 6.1035e-07
# Epoch 143/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 6.1035e-07
# Epoch 144/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 6.1035e-07
# Epoch 145/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 6.1035e-07
# Epoch 146/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 6.1035e-07
# Epoch 147/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 6.1035e-07
# Epoch 148/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 6.1035e-07
# Epoch 149/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 6.1035e-07
# Epoch 150/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 6.1035e-07
# Epoch 151/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0076
# Epoch 151: ReduceLROnPlateau reducing learning rate to 3.0517577442878974e-07.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 6.1035e-07
# Epoch 152/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 3.0518e-07
# Epoch 153/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 3.0518e-07
# Epoch 154/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 3.0518e-07
# Epoch 155/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 3.0518e-07
# Epoch 156/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 3.0518e-07
# Epoch 157/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 3.0518e-07
# Epoch 158/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.0518e-07
# Epoch 159/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.0518e-07
# Epoch 160/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.0518e-07
# Epoch 161/400
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0081
# Epoch 161: ReduceLROnPlateau reducing learning rate to 1.5258788721439487e-07.
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 3.0518e-07
# Epoch 162/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 1.5259e-07
# Epoch 163/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0077 - lr: 1.5259e-07
# Epoch 164/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0084 - lr: 1.5259e-07
# Epoch 165/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0081 - lr: 1.5259e-07
# Epoch 166/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.5259e-07
# Epoch 167/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.5259e-07
# Epoch 168/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.5259e-07
# Epoch 169/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.5259e-07
# Epoch 170/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0077 - lr: 1.5259e-07
# Epoch 171/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0077
# Epoch 171: ReduceLROnPlateau reducing learning rate to 7.629394360719743e-08.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.5259e-07
# Epoch 172/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 7.6294e-08
# Epoch 173/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 7.6294e-08
# Epoch 174/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0083 - lr: 7.6294e-08
# Epoch 175/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 7.6294e-08
# Epoch 176/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 7.6294e-08
# Epoch 177/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 7.6294e-08
# Epoch 178/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 7.6294e-08
# Epoch 179/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 7.6294e-08
# Epoch 180/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 7.6294e-08
# Epoch 181/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0079
# Epoch 181: ReduceLROnPlateau reducing learning rate to 3.814697180359872e-08.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 7.6294e-08
# Epoch 182/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 3.8147e-08
# Epoch 183/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0083 - lr: 3.8147e-08
# Epoch 184/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.8147e-08
# Epoch 185/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 3.8147e-08
# Epoch 186/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 3.8147e-08
# Epoch 187/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 3.8147e-08
# Epoch 188/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0082 - lr: 3.8147e-08
# Epoch 189/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 3.8147e-08
# Epoch 190/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0078 - lr: 3.8147e-08
# Epoch 191/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0080
# Epoch 191: ReduceLROnPlateau reducing learning rate to 1.907348590179936e-08.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 3.8147e-08
# Epoch 192/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.9073e-08
# Epoch 193/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0079 - lr: 1.9073e-08
# Epoch 194/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0081 - lr: 1.9073e-08
# Epoch 195/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.9073e-08
# Epoch 196/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.9073e-08
# Epoch 197/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.9073e-08
# Epoch 198/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 1.9073e-08
# Epoch 199/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.9073e-08
# Epoch 200/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0077 - lr: 1.9073e-08
# Epoch 201/400
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0084
# Epoch 201: ReduceLROnPlateau reducing learning rate to 1e-08.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.9073e-08
# Epoch 202/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 203/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 204/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 205/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 206/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 207/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 208/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 209/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 210/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 211/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 212/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 213/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 214/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 215/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 216/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 217/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 218/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 219/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 220/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 221/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 222/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 223/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 224/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 225/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 226/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 227/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 228/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 229/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 230/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 231/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 232/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 233/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 234/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 235/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 236/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 237/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 238/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 239/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 240/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 241/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 242/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 243/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 244/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 245/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 246/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 247/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 248/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 249/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 250/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 251/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 252/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 253/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 254/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 255/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 256/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 257/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 258/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 259/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 260/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 261/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 262/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 263/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 264/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 265/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 266/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 267/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 268/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 269/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 270/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 271/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 272/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 273/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 274/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 275/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 276/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 277/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 278/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 279/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0083 - lr: 1.0000e-08
# Epoch 280/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 281/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 282/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 283/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 284/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 285/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 286/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 287/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 288/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 289/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 290/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 291/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 292/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 293/400
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 294/400
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 295/400
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 296/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 297/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 298/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 299/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 300/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 301/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 302/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 303/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 304/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 305/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 306/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 307/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 308/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 309/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 310/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 311/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 312/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 313/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 314/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 315/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 316/400
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 317/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 318/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 319/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 320/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 321/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 322/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 323/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 324/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 325/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 326/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 327/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 328/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0083 - lr: 1.0000e-08
# Epoch 329/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 330/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 331/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 332/400
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 333/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 334/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 335/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 336/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 337/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 338/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 339/400
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 340/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 341/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 342/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 343/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 344/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0088 - lr: 1.0000e-08
# Epoch 345/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 346/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 347/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 348/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 349/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 350/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 351/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 352/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 353/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 354/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0077 - lr: 1.0000e-08
# Epoch 355/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 356/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 357/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 358/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 359/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 360/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 361/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 362/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 363/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 364/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 365/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 366/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 367/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 368/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 369/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 370/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 371/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 372/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 373/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 374/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 375/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 376/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 377/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 378/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 379/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 380/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 381/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0083 - lr: 1.0000e-08
# Epoch 382/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 383/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 384/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 385/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 386/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 387/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 388/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 389/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 390/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 391/400
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0078 - lr: 1.0000e-08
# Epoch 392/400
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 393/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 394/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 395/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 396/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - lr: 1.0000e-08
# Epoch 397/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0079 - lr: 1.0000e-08
# Epoch 398/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - lr: 1.0000e-08
# Epoch 399/400
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - lr: 1.0000e-08
# Epoch 400/400
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - lr: 1.0000e-08

# %% [markdown]
# ### Predict 예측

# %%
val_y_pred = autoencoder.predict(select_val_x)
# Out:
# 890/890 [==============================] - 2s 2ms/step

# %% [markdown]
# #### 예측값 코사인유사도 계산

# %%
from numpy import dot
from numpy.linalg import norm

def cos_sim(A, B):
  return dot(A, B)/(norm(A)*norm(B))

# %%
def cosine_similarity(true, pred):
  diff = []
  for i in range(len(true)):
    diff.append(cos_sim(true[i], pred[i]))
  diff = pd.Series(diff)
  return np.array(diff)

# %% [markdown]
# #### 예측 라벨링

# %%
val_AE_pred = np.where(cosine_similarity(select_val_x, val_y_pred)>0.9883, 0, 1)

# %%
pd.DataFrame(val_total_y[val_total_y != val_AE_pred]).value_counts()
# Out:
# Class
# 0        191
# 1         28
# dtype: int64

# %%
val_AE_score = f1_score(val_total_y, val_AE_pred, average='macro')
print(f'Validation F1 Score : [{val_AE_score}]')
print(classification_report(val_total_y, val_AE_pred))
# Out:
# Validation F1 Score : [0.5070374269939165]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     28432
#            1       0.01      0.07      0.02        30
#
#     accuracy                           0.99     28462
#    macro avg       0.50      0.53      0.51     28462
# weighted avg       1.00      0.99      1.00     28462

# %%
# (0,0)=>0  | (1,0)=>1  | (0,1)=>0  | (1,1)=>1
from collections import Counter

def mode (x) :
    cnt = Counter(x)
    mode = cnt.most_common(1)
    return mode[0][0]

# %%
def get_ensemble_pred(test):
  # pred EE
  print('EE_model')
  test_EE_pred = EE_model.predict(test)
  test_EE_pred = get_pred_label(test_EE_pred)

  # AE
  print('AE_model')
  test_AE_pred = autoencoder.predict(test)
  test_AE_pred = np.where(cosine_similarity(test, test_AE_pred)>0.974, 0, 1)

  preds = pd.DataFrame(zip(test_EE_pred, test_AE_pred))
  preds.columns = ['pred_EE', 'pred_AE']
  
  return preds, preds.apply(mode,axis = 1)

# %%
test_pred = get_ensemble_pred(select_test)[1]
# Out:
# EE_model
# AE_model
# 4454/4454 [==============================] - 8s 2ms/step

# %%
test_pred.value_counts()
# Out:
# 0    142236
# 1       267
# dtype: int64

# %%
val_pred = get_ensemble_pred(select_val_x)[1]
# Out:
# EE_model
# AE_model
# 890/890 [==============================] - 2s 2ms/step

# %%
pd.DataFrame(val_total_y[val_total_y != val_pred]).value_counts()
# Out:
# Class
# 1        10
# 0         8
# dtype: int64

# %%
val_score = f1_score(val_total_y, val_pred, average='macro')
print(f'Validation F1 Score : [{val_score}]')
print(classification_report(val_total_y, val_pred))
# Out:
# Validation F1 Score : [0.8446693194042376]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.71      0.67      0.69        30
#
#     accuracy                           1.00     28462
#    macro avg       0.86      0.83      0.84     28462
# weighted avg       1.00      1.00      1.00     28462
